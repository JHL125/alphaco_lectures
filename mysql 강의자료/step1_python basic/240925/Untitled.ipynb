# %%
x = int(input("숫자를 입력하세요.."))
if x >= 90:
    print("Pass")

# %%
x =int(input("숫자를 입력하세요.."))
if x>= 90:
    print("pass")
# Out:
# 숫자를 입력하세요.. 50

# %%
반복문

# %%
for i in range(3):
    print("안녕하세요")
# Out:
# 안녕하세요
# 안녕하세요
# 안녕하세요

# %%
from collections.abc import Sequence

my_num = 100
my_list = [1, 2, 3]
my_string = "hello"

is_num = isinstance(my_num, Sequence)
is_list = isinstance(my_list, Sequence)
is_string = isinstance(my_string, Sequence)

print(is_num)
print(is_list)
print(is_string)
# Out:
# False
# True
# True

# %%
from collections.abc import Sequence

# %%
my_num = 100
my_list = [1. 2. 3]
my_string = "hello"

is_num = isinstance(my_num, Sequence)
is_list = isinstance(my_list, Sequence)
is_string = isinstance(is_string)
# Out:
#   Cell In[13], line 2
#     my_list = [1. 2. 3]
#                ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
my_num = 100
my_list = [1. 2. 3]
my_string = "hello"

is_num = isinstance(my_num, Sequence)
is_list = isinstance(my_list, Sequence)
is_string = isinstance(is_string)
# Out:
#   Cell In[14], line 2
#     my_list = [1. 2. 3]
#                ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
for i in my_string:
    print(i)

# %%
from collections.abc import Sequence

my_num = 100
my_list = [1.2.3]
my_string = "hello"

is_num = isinstance(my_num, Sequesnce)
is_list = isinstance(

# %%
for i in my_list:
    print(i)
# Out:
# 1
# 2
# 3

# %%
for i in my_string:
    print(i)
# Out:
# h
# e
# l
# l
# o

# %%
list(range(3))
# Out:
# [0, 1, 2]

# %%
tuple(range(3))
# Out:
# (0, 1, 2)

# %%
for i in my_string:
    print(i)
# Out:
# h
# e
# l
# l
# o

# %%
list(range(3))
# Out:
# [0, 1, 2]

# %%
tuple(range(3))
# Out:
# (0, 1, 2)

# %%
numbers = [1, 2, 3, 4, 5, 6]
result = []
for x in numbers:
    my_1st_func()
    if x % 2 == 0:
        result.append(x)
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 4
#       2 result = []
#       3 for x in numbers:
# ----> 4     my_1st_func()
#       5     if x % 2 == 0:
#       6         result.append(x)
#
# NameError: name 'my_1st_func' is not defined

# %%
fruits = ["apple", "banana", "cherry"]

for fruit in fruits:
    print(f"I like {fruit}")
# Out:
# I like apple
# I like banana
# I like cherry

# %%
fruits = ["apple", "banana", "cherry"]

for fruit in fruits:
    print(f"I like {fruit}")
# Out:
# I like apple
# I like banana
# I like cherry
